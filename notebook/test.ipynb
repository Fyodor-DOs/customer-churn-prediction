# %%
# Melihat data berdasarkan label spesifik pada kolom 'severity'
import pandas as pd

df = pd.read_csv('../output/data_with_severity.csv')
label_spesifik = 1 # Ganti dengan label yang ingin dilihat
filtered_df = df[df['predicted_severity'] == label_spesifik]
filtered_df
# Out:
#            kode_user                                            message  \
# 0             KN0627  Brarti 450k 100mbps utk 3bulan tanpa bayar mod...
# 1             KP2257                               Ini bukti tf.nya kak
# 2     KM0752, KM1492  Bentar mb tunggu info yg di rumah sdh nyala be...
# 4     KJ2224, KI1388  Kak nomor wa  untuk lapor gangguan nya ganti kah?
# 5             KP2255                        aku td mengajukan pasang ..
# ...              ...                                                ...
# 4289          AT0025                            Minta tolong di cek kan
# 4290          KN0627                                 Yg paket superstar
# 4291          KI1479                               Kak saya habis bayar
# 4292          KN0504            ngaruh ke biaya tagihan perbulan ga kak
# 4293          KT2104  Nanti KLO sdah tak transfer kak...KLO teknisin...
#
#                                              clean_text  severity  \
# ...
